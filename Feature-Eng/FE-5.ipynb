# %%
# FE
# excercise-5 ( target encoding )

# used to boost categorical columns ( one's with high cardinality/unique values )

# requires the endcoding data to be seperated form the training data 

# requires smoothing ( m_estimate ) to avoid overfitting 

# how to do target encoding ? ( it forms new features based on relationship of target with them {columns that are target encoded})

# divide the encode data from the train data 

X = df.copy()
y = X.pop('Rating')

X_encode = X.sample(frac=0.25)
y_encode = y[X_encode.index]
X_pretrain = X.drop(X_encode.index)
y_train = y[X_pretrain.index]

# then do the target encoding to form the new train data set 

from category_encoders import MEstimateEncoder

encoder = MEstimateEncoder(cols=["cols_with_high_cadinality"] , m = 2 ) # the greater the m , the more smoothing is performed ( the new feature is more close to the overall mean 
# {to avoid the chances of very less appearing data altering results})

encoder.fit(X_encode , y_encode)

X_train = encoder.transform(X_pretrain)

# now the target encoding is done ( efficiently with smoothing ) , and this data can be used to train a model ( with will most likely have lower MEA )
