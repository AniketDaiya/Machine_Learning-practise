# %%
# Machine_Leaning-practice
# excercise-1 (basic data exploration)


# how to read a data(csv_file) using pandas (a DataFrame in pandas)
import pandas as pd
variable_name = pd.read_csv(file_path)

# how to describe various perimeters of data to understand it better , 8 (count{non empty},mean,std,min,25,50,75,max)
variable_name.describe()
