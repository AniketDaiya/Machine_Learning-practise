# %%
# Machine_Learning-practice
# excercise-5 (Random Forests more sophisticated ml algo)

# using Random Froests rather than decision tree ; because random forest uses average of combination of trees
# and is much more accurate than decision tree ( even without finetuning with parameters like max_leaf_nodes)
# also Random forest works just fine on default parameters ! 
from sklearn ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split

rf_model = RandomForestRegressor(random_state=1)
rf_model.fit(train_X,train_y)
predicition = rf_model.predict(val_X)
mea = mean_absolute_error(val_y,prediction)
