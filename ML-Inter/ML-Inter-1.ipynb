# %%
# ML-Inter
# excercise-1 (intorduction/recap of prev lessions)

# use train_size , text_size to specifically split the data for model validation 

from sklearn.model_selection import train_test_split

X_train , X_test , y_train , y_test = train_test_split( X , y , train_size = 0.7 , test_size = 0.3 , random_state = 0 )

# use different parametes like (n_estimators , criterion , min_sample_split , max_depth) with random forest regression model to improve it's quality
# here by default randomforest uses the meansquareerror (MSE) criterion , which takes less time than MAE for larger datasets

from sklearn.ensemble import RandomForestRegressor

model = RandomForestRegressor( n_estimators = 500 , criterion='absolute_error' , max_sample_split = 20 , max_depth = 8 , random_state = 0 )
# here min_sample_split , defines the numbers of values a node of tree can hold before it get's split 
# here n_estimators , define the numbers of total trees in the Random Forest 

# to output your predictions as a CSV file do 

import pandas as pd

output = pd.DataFrame({'Id' : X_test.index , 'Predictions' : prediction})

output.to_csv("results.csv" , index = False)
